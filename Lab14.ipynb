# %%
pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\asus\anaconda3\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\asus\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\asus\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\asus\anaconda3\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\asus\anaconda3\lib\site-packages (from mlxtend) (3.9.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\asus\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\asus\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 5.8 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules, fpgrowth

# Завантаження датасету
df = pd.read_csv('clinicHeart.csv')

# Перевірка на пропущені значення
df.fillna(0, inplace=True)

# Перетворення числових даних у бінарний формат (0/1)
df_bin = df.copy()
for col in df_bin.columns:
    if df_bin[col].nunique() > 2:  # Якщо більше двох унікальних значень
        df_bin[col] = pd.cut(df_bin[col], bins=2, labels=[0, 1], duplicates='drop')

df_bin = df_bin.astype(bool).astype(int)  # Перетворюємо у формат 0/1

# Перевіряємо, чи всі значення тепер 0 або 1
assert df_bin.isin([0, 1]).all().all(), "Не всі значення 0 або 1!"

### Пункт 1: Бібліотечна реалізація Apriori
frequent_itemsets_apriori = apriori(df_bin, min_support=0.05, use_colnames=True)
rules_apriori = association_rules(frequent_itemsets_apriori, metric="confidence", min_threshold=0.5)
print("\n=== Пункт 1: Бібліотечна реалізація Apriori ===")
print("Apriori Rules:\n", rules_apriori)

### Пункт 2: Бібліотечна реалізація FP-Growth
frequent_itemsets_fpgrowth = fpgrowth(df_bin, min_support=0.05, use_colnames=True)
rules_fpgrowth = association_rules(frequent_itemsets_fpgrowth, metric="confidence", min_threshold=0.5)
print("\n=== Пункт 2: Бібліотечна реалізація FP-Growth ===")
print("FP-Growth Rules:\n", rules_fpgrowth)

### Пункт 3: Власна реалізація Apriori
def apriori_custom(dataset, min_support=0.05):
    """ Власна реалізація алгоритму Apriori """
    def support_count(itemset):
        return sum(dataset[list(itemset)].all(axis=1))

    # Генерація 1-елементних наборів
    items = {frozenset([col]): support_count([col]) for col in dataset.columns}
    items = {k: v / len(dataset) for k, v in items.items() if v / len(dataset) >= min_support}
    
    frequent_itemsets = list(items.items())  # Часті набори

    # Генерація наборів більшої довжини
    def generate_candidates(itemsets, k):
        candidates = set()
        for i in range(len(itemsets)):
            for j in range(i + 1, len(itemsets)):
                union_set = itemsets[i][0] | itemsets[j][0]
                if len(union_set) == k:
                    candidates.add(union_set)
        return candidates

    # Рекурсивна генерація частих наборів
    k = 2
    while True:
        candidates = generate_candidates(frequent_itemsets, k)
        new_itemsets = {itemset: support_count(list(itemset)) / len(dataset) for itemset in candidates}
        new_itemsets = {k: v for k, v in new_itemsets.items() if v >= min_support}
        
        if not new_itemsets:
            break
        
        frequent_itemsets.extend(new_itemsets.items())
        k += 1

    return frequent_itemsets

# Виклик власного Apriori
frequent_itemsets_apriori_custom = apriori_custom(df_bin, min_support=0.05)
print("\n=== Пункт 3: Apriori (Власна реалізація) ===")
print("Apriori Custom Frequent Itemsets:\n", frequent_itemsets_apriori_custom)

### Пункт 4: Власна реалізація FP-Growth
class FPNode:
    def __init__(self, item, count, parent=None):
        self.item = item
        self.count = count
        self.parent = parent
        self.children = {}

def fpgrowth_custom(dataset, min_support=0.05):
    """ Власна реалізація алгоритму FP-Growth """
    def build_fptree(dataset, min_support):
        # Підрахунок частоти елементів
        item_counts = dataset.sum(axis=0)
        item_counts = item_counts[item_counts / len(dataset) >= min_support]
        item_counts = item_counts.sort_values(ascending=False)

        # Фільтрація стовпців, які не відповідають мінімальній підтримці
        dataset = dataset[item_counts.index]

        # Створення кореневого вузла дерева
        root = FPNode(None, 1)

        # Створення FP-дерева
        for _, transaction in dataset.iterrows():
            transaction = set(transaction[transaction == 1].index)
            current_node = root
            for item in sorted(transaction, key=lambda x: item_counts[x], reverse=True):
                if item not in current_node.children:
                    current_node.children[item] = FPNode(item, 1, current_node)
                else:
                    current_node.children[item].count += 1
                current_node = current_node.children[item]
        
        return root, item_counts

    def mine_fp_tree(node, prefix, item_counts, min_support, frequent_itemsets):
        # Збирання частих множин з FP-дерева
        if node.item:
            frequent_itemsets.append((prefix + [node.item], node.count))
        
        # Рекурсивний обхід дітей
        for item, child in node.children.items():
            mine_fp_tree(child, prefix + [item], item_counts, min_support, frequent_itemsets)
    
    # Побудова дерева та видобуток частих множин
    root, item_counts = build_fptree(dataset, min_support)
    frequent_itemsets = []
    mine_fp_tree(root, [], item_counts, min_support, frequent_itemsets)

    return frequent_itemsets

# Виклик власного FP-Growth
frequent_itemsets_fpgrowth_custom = fpgrowth_custom(df_bin, min_support=0.05)
print("\n=== Пункт 4: FP-Growth (Власна реалізація) ===")
print("FP-Growth Custom Frequent Itemsets:\n", frequent_itemsets_fpgrowth_custom)

### Пункт 5: Власна реалізація Eclat
def eclat(dataset, min_support=0.05):
    """ Реалізація алгоритму Eclat """
    def support_count(itemset):
        return sum(dataset[list(itemset)].all(axis=1))

    items = {frozenset([col]): support_count([col]) for col in dataset.columns}
    items = {k: v / len(dataset) for k, v in items.items() if v / len(dataset) >= min_support}
    
    if not items:  # Якщо немає частих множин — повертаємо порожній список
        return []

    def recursive_eclat(prefix, items):
        """ Рекурсивна генерація частих множин """
        while items:
            item, support = items.popitem()
            yield (prefix | item, support)
            new_items = {
                other_item: support_count(prefix | item | other_item) / len(dataset)
                for other_item in items.keys()
            }
            new_items = {k: v for k, v in new_items.items() if v >= min_support}
            if new_items:
                yield from recursive_eclat(prefix | item, new_items)
    
    return list(recursive_eclat(set(), items))

# Виклик Eclat
eclat_rules = eclat(df_bin, min_support=0.05)
print("\n=== Пункт 5: Eclat (Власна реалізація) ===")
print("Eclat Rules:\n", eclat_rules)
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# C:\Users\Asus\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# === Пункт 1: Бібліотечна реалізація Apriori ===
# Apriori Rules:
#                                  antecedents           consequents  \
# 0                                     (age)        (serum_sodium)
# 1                                     (age)                 (sex)
# 2                       (ejection_fraction)             (anaemia)
# 3                     (high_blood_pressure)             (anaemia)
# 4                                 (anaemia)        (serum_sodium)
# ..                                      ...                   ...
# 206           (anaemia, time, smoking, sex)        (serum_sodium)
# 207  (anaemia, time, smoking, serum_sodium)                 (sex)
# 208   (anaemia, sex, smoking, serum_sodium)                (time)
# 209                (anaemia, time, smoking)   (sex, serum_sodium)
# 210                 (anaemia, sex, smoking)  (time, serum_sodium)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 0                0.2714              0.9224   0.2628    0.968312  1.049775
# 1                0.2714              0.6456   0.1894    0.697863  1.080952
# 2                0.1876              0.4744   0.0978    0.521322  1.098908
# 3                0.3648              0.4744   0.1844    0.505482  1.065520
# 4                0.4744              0.9224   0.4400    0.927487  1.005515
# ..                  ...                 ...      ...         ...       ...
# 206              0.0614              0.9224   0.0610    0.993485  1.077066
# 207              0.0614              0.6456   0.0610    0.993485  1.538856
# 208              0.1154              0.4368   0.0610    0.528596  1.210156
# 209              0.0618              0.6010   0.0610    0.987055  1.642354
# 210              0.1160              0.3976   0.0610    0.525862  1.322591
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                 1.0  0.012461    2.448912       0.065077  0.282277
# 1                 1.0  0.014184    1.172978       0.102786  0.260308
# 2                 1.0  0.008803    1.098024       0.110790  0.173343
# 3                 1.0  0.011339    1.062854       0.096805  0.281613
# 4                 1.0  0.002413    1.070158       0.010436  0.459866
# ..                ...       ...         ...            ...       ...
# 206               1.0  0.004365   11.911600       0.076232  0.066103
# 207               1.0  0.021360   54.400400       0.373073  0.094427
# 208               1.0  0.010593    1.194729       0.196315  0.124186
# 209               1.0  0.023858   30.822750       0.416881  0.101363
# 210               1.0  0.014878    1.270516       0.275914  0.134777
#
#      certainty  kulczynski
# 0     0.591655    0.626611
# 1     0.147469    0.495617
# 2     0.089273    0.363739
# 3     0.059137    0.447092
# 4     0.065559    0.702252
# ..         ...         ...
# 206   0.916048    0.529809
# 207   0.981618    0.543986
# 208   0.162990    0.334124
# 209   0.967556    0.544276
# 210   0.212918    0.339641
#
# [211 rows x 14 columns]
#
# === Пункт 2: Бібліотечна реалізація FP-Growth ===
# FP-Growth Rules:
#                             antecedents          consequents  \
# 0                                (sex)       (serum_sodium)
# 1                       (serum_sodium)                (sex)
# 2                            (smoking)                (sex)
# 3                            (smoking)       (serum_sodium)
# 4                       (sex, smoking)       (serum_sodium)
# ..                                 ...                  ...
# 206           (ejection_fraction, age)       (serum_sodium)
# 207           (ejection_fraction, sex)       (serum_sodium)
# 208  (ejection_fraction, serum_sodium)                (sex)
# 209                (ejection_fraction)  (sex, serum_sodium)
# 210       (ejection_fraction, smoking)       (serum_sodium)
#
#      antecedent support  consequent support  support  confidence      lift  \
# 0                0.6456              0.9224   0.6010    0.930917  1.009233
# 1                0.9224              0.6456   0.6010    0.651561  1.009233
# 2                0.3118              0.6456   0.2976    0.954458  1.478405
# 3                0.3118              0.9224   0.2928    0.939064  1.018065
# 4                0.2976              0.9224   0.2788    0.936828  1.015642
# ..                  ...                 ...      ...         ...       ...
# 206              0.0690              0.9224   0.0672    0.973913  1.055847
# 207              0.1040              0.9224   0.1038    0.998077  1.082043
# 208              0.1826              0.6456   0.1038    0.568456  0.880507
# 209              0.1876              0.6010   0.1038    0.553305  0.920640
# 210              0.0506              0.9224   0.0506    1.000000  1.084128
#
#      representativity  leverage  conviction  zhangs_metric   jaccard  \
# 0                 1.0  0.005499    1.123286       0.025816  0.621510
# 1                 1.0  0.005499    1.017108       0.117900  0.621510
# 2                 1.0  0.096302    7.781825       0.470205  0.451046
# 3                 1.0  0.005196    1.273457       0.025784  0.311026
# 4                 1.0  0.004294    1.228391       0.021926  0.296218
# ..                ...       ...         ...            ...       ...
# 206               1.0  0.003554    2.974667       0.056813  0.072712
# 207               1.0  0.007870   40.352000       0.084624  0.112508
# 208               1.0 -0.014087    0.821237      -0.142385  0.143291
# 209               1.0 -0.008948    0.893227      -0.095927  0.151577
# 210               1.0  0.003927         inf       0.081736  0.054857
#
#      certainty  kulczynski
# 0     0.109755    0.791239
# 1     0.016820    0.791239
# 2     0.871495    0.707712
# 3     0.214736    0.628248
# 4     0.185927    0.619541
# ..         ...         ...
# 206   0.663828    0.523383
# 207   0.975218    0.555305
# 208  -0.217676    0.364618
# 209  -0.119537    0.363009
# 210   1.000000    0.527428
#
# [211 rows x 14 columns]
#
# === Пункт 3: Apriori (Власна реалізація) ===
# Apriori Custom Frequent Itemsets:
#  [(frozenset({'age'}), 0.2714), (frozenset({'anaemia'}), 0.4744), (frozenset({'diabetes'}), 0.4394), (frozenset({'ejection_fraction'}), 0.1876), (frozenset({'high_blood_pressure'}), 0.3648), (frozenset({'serum_sodium'}), 0.9224), (frozenset({'sex'}), 0.6456), (frozenset({'smoking'}), 0.3118), (frozenset({'time'}), 0.4368), (frozenset({'DEATH_EVENT'}), 0.3136), (frozenset({'anaemia', 'DEATH_EVENT'}), 0.1614), (frozenset({'anaemia', 'age'}), 0.134), (frozenset({'smoking', 'age'}), 0.0906), (frozenset({'anaemia', 'diabetes'}), 0.209), (frozenset({'DEATH_EVENT', 'sex'}), 0.2148), (frozenset({'anaemia', 'serum_sodium'}), 0.44), (frozenset({'high_blood_pressure', 'serum_sodium'}), 0.3358), (frozenset({'ejection_fraction', 'serum_sodium'}), 0.1826), (frozenset({'time', 'serum_sodium'}), 0.3976), (frozenset({'diabetes', 'age'}), 0.0884), (frozenset({'sex', 'smoking'}), 0.2976), (frozenset({'anaemia', 'smoking'}), 0.1234), (frozenset({'DEATH_EVENT', 'diabetes'}), 0.1352), (frozenset({'high_blood_pressure', 'smoking'}), 0.108), (frozenset({'high_blood_pressure', 'sex'}), 0.215), (frozenset({'time', 'sex'}), 0.2858), (frozenset({'diabetes', 'smoking'}), 0.0986), (frozenset({'DEATH_EVENT', 'high_blood_pressure'}), 0.1354), (frozenset({'DEATH_EVENT', 'serum_sodium'}), 0.2734), (frozenset({'time', 'smoking'}), 0.1374), (frozenset({'serum_sodium', 'age'}), 0.2628), (frozenset({'diabetes', 'sex'}), 0.2472), (frozenset({'diabetes', 'serum_sodium'}), 0.3868), (frozenset({'ejection_fraction', 'smoking'}), 0.0506), (frozenset({'high_blood_pressure', 'diabetes'}), 0.152), (frozenset({'time', 'diabetes'}), 0.2008), (frozenset({'ejection_fraction', 'sex'}), 0.104), (frozenset({'anaemia', 'sex'}), 0.2868), (frozenset({'time', 'high_blood_pressure'}), 0.1274), (frozenset({'ejection_fraction', 'high_blood_pressure'}), 0.0796), (frozenset({'anaemia', 'ejection_fraction'}), 0.0978), (frozenset({'ejection_fraction', 'time'}), 0.0734), (frozenset({'sex', 'age'}), 0.1894), (frozenset({'DEATH_EVENT', 'smoking'}), 0.0998), (frozenset({'DEATH_EVENT', 'age'}), 0.1312), (frozenset({'smoking', 'serum_sodium'}), 0.2928), (frozenset({'ejection_fraction', 'diabetes'}), 0.0732), (frozenset({'anaemia', 'high_blood_pressure'}), 0.1844), (frozenset({'anaemia', 'time'}), 0.1936), (frozenset({'high_blood_pressure', 'age'}), 0.1224), (frozenset({'ejection_fraction', 'age'}), 0.069), (frozenset({'time', 'age'}), 0.1044), (frozenset({'sex', 'serum_sodium'}), 0.601), (frozenset({'DEATH_EVENT', 'diabetes', 'sex'}), 0.0734), (frozenset({'high_blood_pressure', 'smoking', 'sex'}), 0.0984), (frozenset({'ejection_fraction', 'serum_sodium', 'age'}), 0.0672), (frozenset({'serum_sodium', 'sex', 'age'}), 0.1832), (frozenset({'diabetes', 'smoking', 'sex'}), 0.0914), (frozenset({'DEATH_EVENT', 'high_blood_pressure', 'sex'}), 0.0816), (frozenset({'anaemia', 'sex', 'smoking'}), 0.116), (frozenset({'ejection_fraction', 'time', 'serum_sodium'}), 0.0714), (frozenset({'anaemia', 'ejection_fraction', 'serum_sodium'}), 0.0948), (frozenset({'sex', 'time', 'serum_sodium'}), 0.2656), (frozenset({'anaemia', 'diabetes', 'serum_sodium'}), 0.1788), (frozenset({'anaemia', 'diabetes', 'time'}), 0.0936), (frozenset({'anaemia', 'DEATH_EVENT', 'high_blood_pressure'}), 0.0734), (frozenset({'anaemia', 'smoking', 'serum_sodium'}), 0.1228), (frozenset({'time', 'smoking', 'serum_sodium'}), 0.1284), (frozenset({'DEATH_EVENT', 'high_blood_pressure', 'age'}), 0.0674), (frozenset({'ejection_fraction', 'diabetes', 'serum_sodium'}), 0.0682), (frozenset({'time', 'diabetes', 'sex'}), 0.1136), (frozenset({'serum_sodium', 'diabetes', 'sex'}), 0.2234), (frozenset({'DEATH_EVENT', 'sex', 'age'}), 0.0978), (frozenset({'anaemia', 'high_blood_pressure', 'sex'}), 0.1012), (frozenset({'time', 'high_blood_pressure', 'sex'}), 0.078), (frozenset({'time', 'sex', 'smoking'}), 0.1364), (frozenset({'sex', 'diabetes', 'age'}), 0.0586), (frozenset({'DEATH_EVENT', 'sex', 'serum_sodium'}), 0.194), (frozenset({'anaemia', 'DEATH_EVENT', 'diab ...
#
# === Пункт 4: FP-Growth (Власна реалізація) ===
# FP-Growth Custom Frequent Itemsets:
#  [(['serum_sodium', 'serum_sodium'], 4612), (['serum_sodium', 'sex', 'sex'], 3005), (['serum_sodium', 'sex', 'smoking', 'smoking'], 170), (['serum_sodium', 'sex', 'smoking', 'ejection_fraction', 'ejection_fraction'], 29), (['serum_sodium', 'sex', 'smoking', 'age', 'age'], 25), (['serum_sodium', 'sex', 'smoking', 'age', 'ejection_fraction', 'ejection_fraction'], 1), (['serum_sodium', 'sex', 'anaemia', 'anaemia'], 1339), (['serum_sodium', 'sex', 'anaemia', 'DEATH_EVENT', 'DEATH_EVENT'], 179), (['serum_sodium', 'sex', 'anaemia', 'DEATH_EVENT', 'age', 'age'], 90), (['serum_sodium', 'sex', 'anaemia', 'DEATH_EVENT', 'age', 'ejection_fraction', 'ejection_fraction'], 11), (['serum_sodium', 'sex', 'anaemia', 'DEATH_EVENT', 'smoking', 'smoking'], 27), (['serum_sodium', 'sex', 'anaemia', 'DEATH_EVENT', 'smoking', 'age', 'age'], 11), (['serum_sodium', 'sex', 'anaemia', 'DEATH_EVENT', 'smoking', 'age', 'ejection_fraction', 'ejection_fraction'], 1), (['serum_sodium', 'sex', 'anaemia', 'time', 'time'], 377), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'high_blood_pressure'], 103), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'DEATH_EVENT', 'DEATH_EVENT'], 3), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'DEATH_EVENT', 'age', 'age'], 1), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'DEATH_EVENT', 'smoking', 'smoking'], 1), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'smoking', 'smoking'], 26), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'smoking', 'age', 'age'], 25), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'smoking', 'age', 'ejection_fraction', 'ejection_fraction'], 25), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'ejection_fraction', 'ejection_fraction'], 17), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'age', 'age'], 12), (['serum_sodium', 'sex', 'anaemia', 'time', 'high_blood_pressure', 'age', 'ejection_fraction', 'ejection_fraction'], 12), (['serum_sodium', 'sex', 'anaemia', 'time', 'smoking', 'smoking'], 157), (['serum_sodium', 'sex', 'anaemia', 'time', 'smoking', 'age', 'age'], 20), (['serum_sodium', 'sex', 'anaemia', 'time', 'smoking', 'ejection_fraction', 'ejection_fraction'], 25), (['serum_sodium', 'sex', 'anaemia', 'time', 'DEATH_EVENT', 'DEATH_EVENT'], 37), (['serum_sodium', 'sex', 'anaemia', 'time', 'DEATH_EVENT', 'smoking', 'smoking'], 23), (['serum_sodium', 'sex', 'anaemia', 'time', 'DEATH_EVENT', 'age', 'age'], 12), (['serum_sodium', 'sex', 'anaemia', 'time', 'DEATH_EVENT', 'ejection_fraction', 'ejection_fraction'], 1), (['serum_sodium', 'sex', 'anaemia', 'time', 'age', 'age'], 5), (['serum_sodium', 'sex', 'anaemia', 'time', 'ejection_fraction', 'ejection_fraction'], 3), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'diabetes'], 423), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'high_blood_pressure'], 60), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'DEATH_EVENT', 'DEATH_EVENT'], 14), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'DEATH_EVENT', 'smoking', 'smoking'], 4), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'DEATH_EVENT', 'smoking', 'age', 'age'], 2), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'DEATH_EVENT', 'age', 'age'], 7), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'DEATH_EVENT', 'age', 'ejection_fraction', 'ejection_fraction'], 5), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'age', 'age'], 2), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'age', 'ejection_fraction', 'ejection_fraction'], 1), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'smoking', 'smoking'], 14), (['serum_sodium', 'sex', 'anaemia', 'diabetes', 'high_blood_pressure', 'smoking', 'age', 'age'], 13), (['serum_so ...
#
# === Пункт 5: Eclat (Власна реалізація) ===
# Eclat Rules:
#  [({'DEATH_EVENT'}, 0.3136), ({'DEATH_EVENT', 'smoking'}, 0.0998), ({'DEATH_EVENT', 'sex', 'smoking'}, 0.0894), ({'DEATH_EVENT', 'sex', 'smoking', 'serum_sodium'}, 0.0796), ({'DEATH_EVENT', 'smoking', 'serum_sodium'}, 0.0898), ({'DEATH_EVENT', 'sex'}, 0.2148), ({'DEATH_EVENT', 'sex', 'serum_sodium'}, 0.194), ({'high_blood_pressure', 'DEATH_EVENT', 'sex', 'serum_sodium'}, 0.0752), ({'diabetes', 'DEATH_EVENT', 'sex', 'serum_sodium'}, 0.0682), ({'anaemia', 'DEATH_EVENT', 'sex', 'serum_sodium'}, 0.0928), ({'DEATH_EVENT', 'anaemia', 'age', 'sex', 'serum_sodium'}, 0.0544), ({'DEATH_EVENT', 'age', 'sex', 'serum_sodium'}, 0.0954), ({'high_blood_pressure', 'DEATH_EVENT', 'sex'}, 0.0816), ({'diabetes', 'DEATH_EVENT', 'sex'}, 0.0734), ({'anaemia', 'DEATH_EVENT', 'sex'}, 0.098), ({'anaemia', 'DEATH_EVENT', 'sex', 'age'}, 0.0544), ({'DEATH_EVENT', 'sex', 'age'}, 0.0978), ({'DEATH_EVENT', 'serum_sodium'}, 0.2734), ({'DEATH_EVENT', 'high_blood_pressure', 'serum_sodium'}, 0.1186), ({'anaemia', 'DEATH_EVENT', 'high_blood_pressure', 'serum_sodium'}, 0.0642), ({'DEATH_EVENT', 'age', 'high_blood_pressure', 'serum_sodium'}, 0.0648), ({'DEATH_EVENT', 'diabetes', 'serum_sodium'}, 0.1126), ({'anaemia', 'DEATH_EVENT', 'serum_sodium'}, 0.1416), ({'anaemia', 'DEATH_EVENT', 'age', 'serum_sodium'}, 0.0782), ({'DEATH_EVENT', 'age', 'serum_sodium'}, 0.1284), ({'DEATH_EVENT', 'high_blood_pressure'}, 0.1354), ({'diabetes', 'DEATH_EVENT', 'high_blood_pressure'}, 0.0614), ({'anaemia', 'DEATH_EVENT', 'high_blood_pressure'}, 0.0734), ({'DEATH_EVENT', 'high_blood_pressure', 'age'}, 0.0674), ({'DEATH_EVENT', 'diabetes'}, 0.1352), ({'anaemia', 'DEATH_EVENT', 'diabetes'}, 0.066), ({'anaemia', 'DEATH_EVENT'}, 0.1614), ({'anaemia', 'DEATH_EVENT', 'age'}, 0.0784), ({'DEATH_EVENT', 'age'}, 0.1312), ({'time'}, 0.4368), ({'time', 'smoking'}, 0.1374), ({'time', 'smoking', 'sex'}, 0.1364), ({'serum_sodium', 'time', 'smoking', 'sex'}, 0.1274), ({'time', 'smoking', 'anaemia', 'sex', 'serum_sodium'}, 0.061), ({'anaemia', 'time', 'smoking', 'sex'}, 0.0614), ({'time', 'smoking', 'serum_sodium'}, 0.1284), ({'anaemia', 'time', 'smoking', 'serum_sodium'}, 0.0614), ({'anaemia', 'time', 'smoking'}, 0.0618), ({'time', 'sex'}, 0.2858), ({'serum_sodium', 'time', 'sex'}, 0.2656), ({'serum_sodium', 'high_blood_pressure', 'time', 'sex'}, 0.0708), ({'serum_sodium', 'diabetes', 'time', 'sex'}, 0.0954), ({'serum_sodium', 'anaemia', 'time', 'sex'}, 0.1224), ({'serum_sodium', 'age', 'time', 'sex'}, 0.0686), ({'high_blood_pressure', 'time', 'sex'}, 0.078), ({'diabetes', 'time', 'sex'}, 0.1136), ({'anaemia', 'diabetes', 'time', 'sex'}, 0.057), ({'anaemia', 'time', 'sex'}, 0.1328), ({'age', 'time', 'sex'}, 0.069), ({'time', 'serum_sodium'}, 0.3976), ({'high_blood_pressure', 'time', 'serum_sodium'}, 0.1138), ({'ejection_fraction', 'time', 'serum_sodium'}, 0.0714), ({'diabetes', 'time', 'serum_sodium'}, 0.1674), ({'anaemia', 'diabetes', 'time', 'serum_sodium'}, 0.0792), ({'anaemia', 'time', 'serum_sodium'}, 0.1784), ({'age', 'time', 'serum_sodium'}, 0.1022), ({'high_blood_pressure', 'time'}, 0.1274), ({'high_blood_pressure', 'diabetes', 'time'}, 0.056), ({'ejection_fraction', 'time'}, 0.0734), ({'diabetes', 'time'}, 0.2008), ({'anaemia', 'diabetes', 'time'}, 0.0936), ({'anaemia', 'time'}, 0.1936), ({'time', 'age'}, 0.1044), ({'smoking'}, 0.3118), ({'sex', 'smoking'}, 0.2976), ({'sex', 'smoking', 'serum_sodium'}, 0.2788), ({'high_blood_pressure', 'sex', 'smoking', 'serum_sodium'}, 0.093), ({'diabetes', 'sex', 'smoking', 'serum_sodium'}, 0.0834), ({'anaemia', 'sex', 'smoking', 'serum_sodium'}, 0.1154), ({'age', 'sex', 'smoking', 'serum_sodium'}, 0.0838), ({'high_blood_pressure', 'sex', 'smoking'}, 0.0984), ({'diabetes', 'sex', 'smoking'}, 0.0914), ({'anaemia', 'sex', 'smoking'}, 0.116), ({'sex', 'smoking', 'age'}, 0.084), ({'smoking', 'serum_sodium'}, 0.2928), ({'high_blood_pressure', 'smoking', 'serum_sodium'}, 0.1024), ({'anaemia', 'high_blood_pressure', 'smoking', 'serum_sodium'}, 0.0506), ({'ejecti ...
